# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_csv(r'C:\Users\bivin\OneDrive\Desktop\SalaryData_Train.csv')
train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
test=pd.read_csv(r'C:\Users\bivin\OneDrive\Desktop\SalaryData_Test.csv')
test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
# Desciptive statistics

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
train.describe(include='all')
# Out:
#                  age workclass education   educationno        maritalstatus  \
# count   30161.000000     30161     30161  30161.000000                30161
# unique           NaN         7        16           NaN                    7
# top              NaN   Private   HS-grad           NaN   Married-civ-spouse
# freq             NaN     22285      9840           NaN                14065
# mean       38.438115       NaN       NaN     10.121316                  NaN
# std        13.134830       NaN       NaN      2.550037                  NaN
# min        17.000000       NaN       NaN      1.000000                  NaN
# 25%        28.000000       NaN       NaN      9.000000                  NaN
# 50%        37.000000       NaN       NaN     10.000000                  NaN
# 75%        47.000000       NaN       NaN     13.000000                  NaN
# max        90.000000       NaN       NaN     16.000000                  NaN
#
# ...

# %%
train.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
train.shape
# Out:
# (30161, 14)

# %%
train.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
test.describe(include='all')
# Out:
#                  age workclass education   educationno        maritalstatus  \
# count   15060.000000     15060     15060  15060.000000                15060
# unique           NaN         7        16           NaN                    7
# top              NaN   Private   HS-grad           NaN   Married-civ-spouse
# freq             NaN     11021      4943           NaN                 6990
# mean       38.768327       NaN       NaN     10.112749                  NaN
# std        13.380676       NaN       NaN      2.558727                  NaN
# min        17.000000       NaN       NaN      1.000000                  NaN
# 25%        28.000000       NaN       NaN      9.000000                  NaN
# 50%        37.000000       NaN       NaN     10.000000                  NaN
# 75%        48.000000       NaN       NaN     13.000000                  NaN
# max        90.000000       NaN       NaN     16.000000                  NaN
#
# ...

# %%
test.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
test.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
test.shape
# Out:
# (15060, 14)

# %%
sns.countplot(x=train['Salary'])
# Out:
# <Axes: xlabel='Salary', ylabel='count'>

# %%
sns.countplot(x=test['Salary'])
# Out:
# <Axes: xlabel='Salary', ylabel='count'>

# %%
train['workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' Self-emp-inc', ' Without-pay'], dtype=object)

# %%
test['workclass'].unique()
# Out:
# array([' Private', ' Local-gov', ' Self-emp-not-inc', ' Federal-gov',
#        ' State-gov', ' Self-emp-inc', ' Without-pay'], dtype=object)

# %%
# correlation anlaysis
sns.heatmap(train.corr(),annot=True)
# Out:
# C:\Users\bivin\AppData\Local\Temp\ipykernel_10380\2873273723.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train.corr(),annot=True)
# <Axes: >

# %%
sns.heatmap(test.corr(),annot=True)
# Out:
# C:\Users\bivin\AppData\Local\Temp\ipykernel_10380\1801411367.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(test.corr(),annot=True)
# <Axes: >

# %%
train.hist()
plt.tight_layout
plt.figure(figsize=(20,20))

# %%
test.hist()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
train.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
# countpot for all categorical columns
cols= ['workclass', 'education','maritalstatus', 'occupation', 'relationship', 'race', 'sex','Salary']

for col in cols:
    plt.figure()
    sns.countplot(x=col,data=train,palette='rainbow')

# %%
# countpot for all categorical columns
cols= ['workclass', 'education','maritalstatus', 'occupation', 'relationship', 'race', 'sex','Salary']

for col in cols:
    plt.figure()
    sns.countplot(x=col,data=test,palette='rainbow')

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

# %%
le=LabelEncoder()
oe=OrdinalEncoder()

# %%
train1=train.iloc[:,:-1].apply(le.fit_transform)
train1
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       22          5          9           12              4           0
# 1       33          4          9           12              2           3
# 2       21          2         11            8              0           5
# 3       36          2          1            6              2           5
# 4       11          2          9           12              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   10          2          7           11              2          12
# 30157   23          2         11            8              2           6
# 30158   41          2         11            8              6           0
# 30159    5          2         11            8              4           0
# 30160   35          3         11            8              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# ...

# %%
train1['Salary']=train['Salary']
train1.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   22          5          9           12              4           0
# 1   33          4          9           12              2           3
# 2   21          2         11            8              0           5
# 3   36          2          1            6              2           5
# 4   11          2          9           12              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             1     4    1           24            0            39      37
# 1             0     4    1            0            0            12      37
# 2             1     4    1            0            0            39      37
# 3             0     2    1            0            0            39      37
# 4             5     2    0            0            0            39       4
#
#    Salary
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K

# %%
test1=test.iloc[:,:-1].apply(le.fit_transform)
test1
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0        8          2          1            6              4           6
# 1       21          2         11            8              2           4
# 2       11          1          7           11              2          10
# 3       27          2         15            9              2           6
# 4       17          2          0            5              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   16          2          9           12              4           9
# 15056   22          2          9           12              0           9
# 15057   21          2          9           12              2           9
# 15058   27          2          9           12              0           0
# 15059   18          3          9           12              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# ...

# %%
test1['Salary']=train['Salary']
test1.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0    8          2          1            6              4           6
# 1   21          2         11            8              2           4
# 2   11          1          7           11              2          10
# 3   27          2         15            9              2           6
# 4   17          2          0            5              4           7
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             3     2    1            0            0            39      37
# 1             0     4    1            0            0            49      37
# 2             0     4    1            0            0            39      37
# 3             0     2    1           87            0            39      37
# 4             1     4    1            0            0            29      37
#
#    Salary
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K

# %%
# splitting train and test data

# %%
xtrain=train1.iloc[:,:13]
ytrain=train1['Salary']

# %%
xtest=test1.iloc[:,:13]
ytest=test1['Salary']

# %%
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (30161, 13)
# (15060, 13)
# (30161,)
# (15060,)

# %% [markdown]
# # Model building

# %%
def norm(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
xtrain=norm(xtrain)
xtest=norm(xtest)

# %%
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (30161, 13)
# (15060, 13)
# (30161,)
# (15060,)

# %%
from sklearn.svm import SVC

# %%
# linear model
linear=SVC(kernel='linear')
linear.fit(xtrain,ytrain)
# Out:
# SVC(kernel='linear')

# %%
ypred=linear.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.700531208499336

# %%
# poly model
poly=SVC(kernel='poly')
poly.fit(xtrain,ytrain)
# Out:
# SVC(kernel='poly')

# %%
ypred1=poly.predict(xtest)

# %%
accuracy_score(ytest,ypred1)
# Out:
# 0.6626826029216467

# %%
# sigmoid model
sigm=SVC(kernel='sigmoid')
sigm.fit(xtrain,ytrain)
# Out:
# SVC(kernel='sigmoid')

# %%
ypred2=sigm.predict(xtest)

# %%
accuracy_score(ytest,ypred2)
# Out:
# 0.6302124833997343

# %%
# rbf model
rbf=SVC(kernel='rbf')
rbf.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
ypred3=rbf.predict(xtest)

# %%
accuracy_score(ytest,ypred3)
# Out:
# 0.6606241699867198

# %%
### linear model has the maximum accuracy of 70%
